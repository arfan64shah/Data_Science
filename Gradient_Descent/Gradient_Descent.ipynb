# %%
# import required libraries
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
dataset = pd.read_csv('test_scores.csv')
dataset
# Out:
#      name  math  cs
# 0   david    92  98
# 1   laura    56  68
# 2  sanjay    88  81
# 3     wei    70  80
# 4    jeff    80  83
# 5   aamir    49  52
# 6  venkat    65  66
# 7   virat    35  30
# 8  arthur    66  68
# 9    paul    67  73

# %%
# split dataset into x as math and y as cs
x = dataset['math']
y = dataset['cs']

# %%
# change dimensions
x = pd.DataFrame(x)
y = pd.DataFrame(y)

# %%
# convert x and y into numpy arrays
x = np.array(x)
y = np.array(y)

# %%
# define model to slope and intercept
model = LinearRegression()

model.fit(x, y)

slope = model.coef_[0]
intercept = model.intercept_

print(slope)
print(intercept)
# Out:
# [1.01773624]
# [1.91521931]

# %%
# define a function to find number of iterations to get minimum error
def gradient_descent(x, y):
    
    slope_curr = 0
    intercept_curr = 0
    iterations = 1000
    learning_rate = 0.0002
    n = len(x)

    for i in range(iterations):
        y_pred = slope_curr * x + intercept_curr
        cost = (1/n) * sum([val**2 for val in (y - y_pred)])

        slope_d = -(2/n) * sum(x * (y - y_pred))
        intercept_d = -(2/n) * sum(y - y_pred)

        slope_curr = slope_curr - learning_rate * slope_d
        intercept_curr = intercept_curr - learning_rate * intercept_d

        print("slope {}, intercept {}, cost {}, iteration {}".format(float(slope), float(intercept), float(cost), i))

gradient_descent(x, y)
# Out:
# slope 1.017736237856933, intercept 1.9152193111568891, cost 5199.1, iteration 0
# slope 1.017736237856933, intercept 1.9152193111568891, cost 4161.482445460163, iteration 1
# slope 1.017736237856933, intercept 1.9152193111568891, cost 3332.2237319269248, iteration 2
# slope 1.017736237856933, intercept 1.9152193111568891, cost 2669.4843523161976, iteration 3
# slope 1.017736237856933, intercept 1.9152193111568891, cost 2139.826383775145, iteration 4
# slope 1.017736237856933, intercept 1.9152193111568891, cost 1716.5264071567592, iteration 5
# slope 1.017736237856933, intercept 1.9152193111568891, cost 1378.2272007804495, iteration 6
# slope 1.017736237856933, intercept 1.9152193111568891, cost 1107.8601808918404, iteration 7
# slope 1.017736237856933, intercept 1.9152193111568891, cost 891.7842215178443, iteration 8
# slope 1.017736237856933, intercept 1.9152193111568891, cost 719.0974036421305, iteration 9
# ...
